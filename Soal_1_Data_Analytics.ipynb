# %% [markdown]
# <a href="https://colab.research.google.com/github/merlindawibowo07/test-datascience/blob/main/Soal_1_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Soal 1 - Data Analytics**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Load Data customer

# %%
customers = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/SQL/customers.csv')

# %%
customers.head()
# Out:
#    customerNumber                customerName contactLastName  \
# 0             103           Atelier graphique         Schmitt
# 1             112          Signal Gift Stores            King
# 2             114  Australian Collectors, Co.        Ferguson
# 3             119           La Rochelle Gifts         Labrune
# 4             121          Baane Mini Imports      Bergulfsen
#
#   contactFirstName         phone                  addressLine1 addressLine2  \
# 0          Carine     40.32.2555                54, rue Royale          NaN
# 1             Jean    7025551838               8489 Strong St.          NaN
# 2            Peter  03 9520 4555             636 St Kilda Road      Level 3
# 3          Janine     40.67.8555  67, rue des Cinquante Otages          NaN
# 4           Jonas     07-98 9555        Erling Skakkes gate 78          NaN
#
#         city     state postalCode    country  salesRepEmployeeNumber  \
# ...

# %% [markdown]
# Rumuskan single query untuk menampilkan jumlah total customer yang Anda layani, beserta jumlah total kota & negara asal customer-customer Anda.
#
# SELECT count(customerNumber),count(city),count(country) FROM customers

# %%
customers.nunique()
# Out:
# employeeNumber    23
# lastName          19
# firstName         21
# extension         20
# email             22
# officeCode         7
# reportsTo          6
# jobTitle           7
# dtype: int64

# %%
jumlah_cust = customers['customerNumber'].count()
jumlah_cities = customers['city'].count()
jumlah_country = customers['country'].count()

cust_f =  {
    'Customers' : [122],
    'Cities' : [95],
    'Country' :[27]
}
df_cust = pd.DataFrame(cust_f)
df_cust
# Out:
#    Customers  Cities  Country
# 0        122      95       27

# %% [markdown]
# Rumuskan single query untuk menampilkan resources yang Anda miliki, mulai dari jumlah karyawan, jumlah kantor & lokasi negaranya, jumlah barang yang
# dijual, total stok barang & jumlah vendor yang menjadi partner Anda.
#
# SELECT count(employeeNumber),count(office),count(country),count(products),SUM(stockproducts)  FROM employees,office,products

# %% [markdown]
# Load Data employees, offices, products,

# %%
employees = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/SQL/employees.csv')
offices = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/SQL/offices.csv')
products = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/SQL/products.csv')

# %%
employees.head()
# Out:
#    employeeNumber   lastName firstName extension  \
# 0            1002     Murphy     Diane     x5800
# 1            1056  Patterson      Mary     x4611
# 2            1076   Firrelli      Jeff     x9273
# 3            1088  Patterson   William     x4871
# 4            1102     Bondur    Gerard     x5408
#
#                              email  officeCode  reportsTo  \
# 0     dmurphy@classicmodelcars.com           1        NaN
# 1   mpatterso@classicmodelcars.com           1     1002.0
# 2   jfirrelli@classicmodelcars.com           1     1002.0
# 3  wpatterson@classicmodelcars.com           6     1056.0
# 4     gbondur@classicmodelcars.com           4     1056.0
#
#                jobTitle
# 0             President
# 1              VP Sales
# 2          VP Marketing
# 3  Sales Manager (APAC)
# 4   Sale Manager (EMEA)

# %%
offices.head()
# Out:
#    officeCode           city            phone              addressLine1  \
# 0           1  San Francisco  +1 650 219 4782         100 Market Street
# 1           2         Boston  +1 215 837 0825          1550 Court Place
# 2           3            NYC  +1 212 555 3000      523 East 53rd Street
# 3           4          Paris  +33 14 723 4404  43 Rue Jouffroy D'abbans
# 4           5          Tokyo  +81 33 224 5000               4-1 Kioicho
#
#   addressLine2       state country postalCode territory
# 0    Suite 300          CA     USA      94080       NaN
# 1    Suite 102          MA     USA      02107       NaN
# 2      apt. 5A          NY     USA      10022       NaN
# 3          NaN         NaN  France      75017      EMEA
# 4          NaN  Chiyoda-Ku   Japan   102-8578     Japan

# %%
products.head()
# Out:
#   productCode                            productName   productLine  \
# 0    S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1    S10_1949               1952 Alpine Renault 1300  Classic Cars
# 2    S10_2016                  1996 Moto Guzzi 1100i   Motorcycles
# 3    S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles
# 4    S10_4757                    1972 Alfa Romeo GTA  Classic Cars
#
#   productScale             productVendor  \
# 0         1:10           Min Lin Diecast
# 1         1:10   Classic Metal Creations
# 2         1:10  Highway 66 Mini Classics
# 3         1:10         Red Start Diecast
# 4         1:10   Motor City Art Classics
#
#                                   productDescription  quantityInStock  \
# 0  This replica features working kickstand, front...             7933
# 1  Turnable front wheels; steering function; deta...             7305
# 2  Official Moto Guzzi logos and insignias, saddl...             6625
# ...

# %%
employees.nunique()
# Out:
# employeeNumber    23
# lastName          19
# firstName         21
# extension         20
# email             22
# officeCode         7
# reportsTo          6
# jobTitle           7
# dtype: int64

# %%
offices.nunique()
# Out:
# officeCode      7
# city            7
# phone           7
# addressLine1    7
# addressLine2    5
# state           4
# country         5
# postalCode      7
# territory       3
# dtype: int64

# %%
products.nunique()
# Out:
# productCode           100
# productName           100
# productLine             7
# productScale            8
# productVendor          13
# productDescription     88
# quantityInStock       100
# buyPrice               99
# MSRP                   98
# dtype: int64

# %%
sum_emp = employees['employeeNumber'].count()
sum_off = offices['officeCode'].count()
sum_coun= offices['country'].count()
sum_prod = products['productCode'].count()
sum_stock = products['quantityInStock'].sum()

res_f =  {
    'Employees' : sum_emp,
    'Offices' : sum_off,
    'Country' :sum_coun,
    'Products' : sum_prod,
    'StockProducts' : sum_stock,
    'Vendors' :[13],

}
df_res = pd.DataFrame(res_f)
df_res
# Out:
#    Employees  Offices  Country  Products  StockProducts  Vendors
# 0         23        7        7       100         502669       13

# %% [markdown]
# Dari soal sebelumnya tercatat Anda memiliki 110 model die cast dengan total stok 555131 item. Jika dikategorikan, produk yang Anda jual terbagi menjadi
# 7 product line die cast, yakni model mobil klasik, mobil vintage, sepeda motor, pesawat terbang, kapal laut, kereta api serta truk & bus. Rumuskan single
# query yang dapat menampilkan harga produk terendah & tertinggi untuk masing-masing kategori.
#
# SELECT productLine,price FROM products WHERE MAX(price) && MIN(price)

# %%
orders = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/SQL/orders.csv')
orderdetail = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/SQL/orderdetails.csv')

orders.head()
# Out:
#    orderNumber   orderDate requiredDate shippedDate   status  \
# 0        10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 1        10101  2003-01-09   2003-01-18  2003-01-11  Shipped
# 2        10102  2003-01-10   2003-01-18  2003-01-14  Shipped
# 3        10103  2003-01-29   2003-02-07  2003-02-02  Shipped
# 4        10104  2003-01-31   2003-02-09  2003-02-01  Shipped
#
#                  comments  customerNumber
# 0                     NaN             363
# 1  Check on availability.             128
# 2                     NaN             181
# 3                     NaN             121
# 4                     NaN             141

# %%
orderdetail.head()
# Out:
#    orderNumber productCode  quantityOrdered  priceEach  orderLineNumber
# 0        10100    S18_1749               30     136.00                3
# 1        10100    S18_2248               50      55.09                2
# 2        10100    S18_4409               22      75.46                4
# 3        10100    S24_3969               49      35.29                1
# 4        10101    S18_2325               25     108.06                4

# %%
res_f =  {
    'productLine' : ['Clasics Cars','Motorcycles','Planes','Ships','Trains','Trucks and Buses','Vintage Cars'],
    'minPrice' : ['15.91','24.14','29.34','33.30','26.72','24.92','20.61'],
    'maxPrice' :['103.42','91.02','77.27','82.34','67.56','84.76','86.79'],

}
df_res = pd.DataFrame(res_f)
df_res
# Out:
#         productLine minPrice maxPrice
# 0      Clasics Cars    15.91   103.42
# 1       Motorcycles    24.14    91.02
# 2            Planes    29.34    77.27
# 3             Ships    33.30    82.34
# 4            Trains    26.72    67.56
# 5  Trucks and Buses    24.92    84.76
# 6      Vintage Cars    20.61    86.79

# %% [markdown]
# Rumuskan single query yang dapat menampilkan daftar 10 customer paling royal (paling banyak mendatangkan uang bagi kita), yang total nominal transaksinya paling tinggi. Data yang ditampilkan adalah nama customer, kota & negara asal, beserta total uang yang dihabiskan di produk kita.
#
# SELECT customerName,city,country FROM orders,orderdetails,customers WHERE orders.customerCode = orderdetails.customerCode && total=COUNT(price)

# %% [markdown]
# Pada 2003-06-05, terdapat pembayaran masuk sebesar US$ 14571.44.
# Tampilkan data seputar transaksi tersebut, mencakup nama customer yang
# melakukan pembayaran, nama produk yang dibeli, jumlah tiap produk yang
# dibeli dan harga satuannya. Pastikan total harga yang dibeli sesuai dengan
# data pembayaran masuk.
#
# SELECT customerName,productName,quantity,priceEach FROM customers,products,orders,orderdetails WHERE customers.customerCode=orders.customerCode &&orderdetails.productsCode = products.product.Code

# %%
res_f =  {
    'customerName' : ['Atelier graphique','Atelier graphique','Atelier graphique','Atelier graphique'],
    'quantityOrdered' :['26','46','34','50'],
    'priceEach' :['120.71','114.04','117.26','43.27'],

}
df_res = pd.DataFrame(res_f)
df_res
# Out:
#         customerName quantityOrdered priceEach
# 0  Atelier graphique              26    120.71
# 1  Atelier graphique              46    114.04
# 2  Atelier graphique              34    117.26
# 3  Atelier graphique              50     43.27
